# %%
import os, sys

notebook_dir = os.getcwd()

#add path
sys.path.append(os.path.abspath(os.path.join(notebook_dir, '..')))

# %%
from scripts.load_data import load_data
from scripts.EDA import *

# %%
data1 = load_data('../../Data/raw_analyst_ratings.csv')
data1
# Out:
# Data loaded successfully!
#          Unnamed: 0                                           headline  \
# 0                 0            Stocks That Hit 52-Week Highs On Friday
# 1                 1         Stocks That Hit 52-Week Highs On Wednesday
# 2                 2                      71 Biggest Movers From Friday
# 3                 3       46 Stocks Moving In Friday's Mid-Day Session
# 4                 4  B of A Securities Maintains Neutral on Agilent...
# ...             ...                                                ...
# 1407323     1413844             Top Narrow Based Indexes For August 29
# 1407324     1413845  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325     1413846  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326     1413847  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327     1413848  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# 0        https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1        https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2        https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3        https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4        https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
# ...                                                    ...                ...
# 1407323  https://www.benzinga.com/news/11/08/1888782/to...      Monica Gerson
# 1407324  https://www.benzinga.com/news/earnings/11/06/1...       Benjamin Lee
# 1407325  https://www.benzinga.com/analyst-ratings/analy...     BenzingaStaffL
# 1407326  https://www.benzinga.com/analyst-ratings/price...          Joe Young
# 1407327  https://www.benzinga.com/news/ipos/11/05/10789...      Allie Wickman
#
#                               date stock
# 0        2020-06-05 10:30:54-04:00     A
# 1        2020-06-03 10:45:20-04:00     A
# 2        2020-05-26 04:30:07-04:00     A
# 3        2020-05-22 12:45:06-04:00     A
# 4        2020-05-22 11:38:59-04:00     A
# ...                            ...   ...
# 1407323        2011-08-29 00:00:00    ZX
# 1407324        2011-06-22 00:00:00    ZX
# 1407325        2011-06-21 00:00:00    ZX
# 1407326        2011-06-21 00:00:00    ZX
# 1407327        2011-05-12 00:00:00    ZX
#
# [1407328 rows x 6 columns]

# %%
data1.isnull().sum()
# Out:
# Unnamed: 0         0
# headline           0
# url                0
# publisher          0
# date               0
# stock              0
# headline_length    0
# sentiment          0
# dtype: int64

# %%
data1.duplicated().sum()
# Out:
# np.int64(0)

# %%
# data1 = data1.sample(n=1000)
perform_eda(data1)
# Out:
# Descriptive Statistics:
#          Unnamed: 0  headline_length   sentiment
# count  9.020000e+02       902.000000  902.000000
# mean   7.134043e+05        70.976718    0.055650
# std    4.092546e+05        38.420139    0.188943
# min    7.440000e+02        11.000000   -1.000000
# 25%    3.526725e+05        47.000000    0.000000
# 50%    7.148460e+05        63.000000    0.000000
# 75%    1.058072e+06        85.000000    0.000000
# max    1.413207e+06       376.000000    1.000000
#
# Headline Length Statistics:
# count    902.000000
# mean      70.976718
# std       38.420139
# min       11.000000
# 25%       47.000000
# 50%       63.000000
# 75%       85.000000
# max      376.000000
# Name: headline_length, dtype: float64
# Top Publishers by Article Count:
# publisher
# Paul Quintaro        154
# Lisa Levin           116
# Benzinga Newsdesk     88
# Monica Gerson         62
# Charles Gross         50
# Eddie Staley          37
# Hal Lindon            32
# ETF Professor         19
# Shanthi Rexaline      18
# Jayson Derrick        17
# Name: count, dtype: int64
# Sentiment Analysis:
# count    902.000000
# mean       0.055650
# std        0.188943
# min       -1.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: sentiment, dtype: float64
# Top Topics from LDA:
# Topic #1:
# ['higher', 'thursday', 'earnings', 'day', 'moving', 'update', 'session', 'market', 'mid', 'stocks']
# Topic #2:
# ['companies', 'dividend', 'share', 'biggest', 'movers', 'yesterday', '52', 'week', 'new', 'stocks']
# Topic #3:
# ['prior', 'preview', 'says', 'premarket', 'market', 'gainers', 'losers', 'reports', 'earnings', 'benzinga']
# Topic #4:
# ['q1', 'shares', 'sees', 'trading', 'estimate', 'reports', 'sales', 'eps', 'est', 'vs']
# Topic #5:
# ['00', 'benzinga', 'buy', 'maintains', 'upgrades', 'raises', 'downgrades', 'target', 'pt', 'price']
